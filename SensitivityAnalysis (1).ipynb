# %% [markdown]
# <h2>Sensitivity Analysis</h2>

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl

# %% [markdown]
# <h3>Changing Urgent Arrival Parameter</h3>
# # we assign Non_urgent arrival 1, 10, 20 and got 4 Replications, then used the average and plotting them. The results are in the parameters changing excel file.

# %%
# Data
x = [1, 10, 20]
y = [114, 387.75, 310.5]

# Configure font
mpl.rc('font', family='Times New Roman')
mpl.rc('font', size=12)

# Create the plot
fig, ax = plt.subplots(figsize=(8, 6))

# Highlight the line by changing its style
ax.plot(x, y, label='Max Queue Length in Reservation Queue', 
        color='red', linewidth=2.5, linestyle='--', marker='o', markersize=8)

# Add title and labels
ax.set_title('Max Queue Length in Reservation Queue', fontsize=14, fontweight='bold')
ax.set_xlabel('Non_urgent arrival rate', fontsize=12)
ax.set_ylabel('Max Queue Length', fontsize=12)

# Add legend and grid
ax.legend()
ax.grid(True, axis='y', linestyle='--', alpha=0.7)

# Display the plot
plt.tight_layout()
fig.show()
#fig.savefig('11.svg', format='svg')




# Data
x = [1, 10, 20]
y = [0.000915921, 0.048181309, 0.071117952]
# Configure font
mpl.rc('font', family='Times New Roman')
mpl.rc('font', size=12)

# Create the plot
fig, ax = plt.subplots(figsize=(8, 6))

# Highlight the line by changing its style
ax.plot(x, y, label='Average Queue Length Non Urgent Patient in Lab Queue', 
        color='red', linewidth=2.5, linestyle='--', marker='o', markersize=8)

# Add title and labels
ax.set_title('Average Queue Length Non Urgent Patient in Lab Queue', fontsize=14, fontweight='bold')
ax.set_xlabel('Non_urgent arrival rate', fontsize=12)
ax.set_ylabel('Average Queue Length', fontsize=12)

# Add legend and grid
ax.legend()
ax.grid(True, axis='y', linestyle='--', alpha=0.7)

# Display the plot
plt.tight_layout()
fig.show()
#fig.savefig('13.svg', format='svg')




# Data
x = [1, 10, 20]
y = [49.78,84.75, 66.08]

# Configure font
mpl.rc('font', family='Times New Roman')
mpl.rc('font', size=12)

# Create the plot
fig, ax = plt.subplots(figsize=(8, 6))


# Highlight the line by changing its style
ax.plot(x, y, label='Pre_Surgery Bed Utilization', 
        color='red', linewidth=2.5, linestyle='--', marker='o', markersize=8)

# Add title and labels
ax.set_title('Pre_Surgery Bed Utilization', fontsize=14, fontweight='bold')
ax.set_xlabel('Non_urgent arrival rate', fontsize=12)
ax.set_ylabel('Bed Utilization', fontsize=12)

# Add legend and grid
ax.legend()
ax.grid(True, axis='y', linestyle='--', alpha=0.7)

# Display the plot
plt.tight_layout()
fig.show()
#fig.savefig('14.svg', format='svg')
# Out:
# C:\Users\Mahshad\AppData\Local\Temp\ipykernel_14428\3016411307.py:27: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# C:\Users\Mahshad\AppData\Local\Temp\ipykernel_14428\3016411307.py:58: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# C:\Users\Mahshad\AppData\Local\Temp\ipykernel_14428\3016411307.py:91: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %% [markdown]
# <h3>Changing Urgent Arrival Rate</h3>
# # we assign urgent arrival 4, 14, 24 and got 4 Replications, then used the average and plotting them. The results are in the parameters changing excel file.

# %%
# Data
x = [4, 14, 24]
y = [19, 20.5, 18.5]

# Configure font
mpl.rc('font', family='Times New Roman')
mpl.rc('font', size=12)

# Create the plot
fig, ax = plt.subplots(figsize=(8, 6))

# Highlight the line by changing its style
ax.plot(x, y, label='Max Queue Length Patients in General Queue', 
        color='red', linewidth=2.5, linestyle='--', marker='o', markersize=8)

# Add title and labels
ax.set_title('Max Queue Length Patients in General Queue', fontsize=14, fontweight='bold')
ax.set_xlabel('Urgent arrival rate', fontsize=12)
ax.set_ylabel('Max Queue Length', fontsize=12)

# Add legend and grid
ax.legend()
ax.grid(True, axis='y', linestyle='--', alpha=0.7)

# Display the plot
plt.tight_layout()
fig.show()
#fig.savefig('21.svg', format='svg')




# Data
x = [4, 14, 24]
y = [3.970713783, 3.663959313, 3.968320682]

# Configure font
mpl.rc('font', family='Times New Roman')
mpl.rc('font', size=12)

# Create the plot
fig, ax = plt.subplots(figsize=(8, 6))

# Highlight the line by changing its style
ax.plot(x, y, label='Average Queue Length  Patients in General Queue', 
        color='red', linewidth=2.5, linestyle='--', marker='o', markersize=8)

# Add title and labels
ax.set_title('Average Queue Length  Patients in General Queue', fontsize=14, fontweight='bold')
ax.set_xlabel('Urgent arrival rate', fontsize=12)
ax.set_ylabel('Average Queue Length', fontsize=12)

# Add legend and grid
ax.legend()
ax.grid(True, axis='y', linestyle='--', alpha=0.7)

# Display the plot
plt.tight_layout()
fig.show()
#fig.savefig('23.svg', format='svg')




# Data
x = [4, 14, 24]
y = [1.42, 1.26, 0.86]

# Configure font
mpl.rc('font', family='Times New Roman')
mpl.rc('font', size=12)

# Create the plot
fig, ax = plt.subplots(figsize=(8, 6))


# Highlight the line by changing its style
ax.plot(x, y, label='Operation Room Bed Utilization', 
        color='red', linewidth=2.5, linestyle='--', marker='o', markersize=8)

# Add title and labels
ax.set_title('Operation Room Bed Utilization', fontsize=14, fontweight='bold')
ax.set_xlabel('Urgent arrival rate', fontsize=12)
ax.set_ylabel('Bed Utilization', fontsize=12)

# Add legend and grid
ax.legend()
ax.grid(True, axis='y', linestyle='--', alpha=0.7)

# Display the plot
plt.tight_layout()
fig.show()
#fig.savefig('24.svg', format='svg')
# Out:
# C:\Users\Mahshad\AppData\Local\Temp\ipykernel_14428\683596723.py:27: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# C:\Users\Mahshad\AppData\Local\Temp\ipykernel_14428\683596723.py:59: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# C:\Users\Mahshad\AppData\Local\Temp\ipykernel_14428\683596723.py:92: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %% [markdown]
# <h3>Changing CCU Service Rate EXP(1/25)</h3>
# # we assign CCU service rate EXP(1/25), EXP(1/35), EXP(1/45) and got 4 Replications, then used the average and plotting them. The results are in the parameters changing excel file.

# %%
# Data
x = [25, 35, 45]
y = [1.25, 3.5, 3.25]

# Configure font
mpl.rc('font', family='Times New Roman')
mpl.rc('font', size=12)

# Create the plot
fig, ax = plt.subplots(figsize=(8, 6))

# Highlight the line by changing its style
ax.plot(x, y, label='Max Queue Length Patients in CCU Queue', 
        color='red', linewidth=2.5, linestyle='--', marker='o', markersize=8)

# Add title and labels
ax.set_title('Max Queue Length Patients in CCU Queue', fontsize=14, fontweight='bold')
ax.set_xlabel('CCU Service rate', fontsize=12)
ax.set_ylabel('Max Queue Length', fontsize=12)

# Add legend and grid
ax.legend()
ax.grid(True, axis='y', linestyle='--', alpha=0.7)

# Display the plot
plt.tight_layout()
fig.show()
#fig.savefig('31.svg', format='svg')


# Data
x = [25, 35, 45]
y = [0.353505493, 0.46747793, 0.509246547]

# Configure font
mpl.rc('font', family='Times New Roman')
mpl.rc('font', size=12)

# Create the plot
fig, ax = plt.subplots(figsize=(8, 6))

# Highlight the line by changing its style
ax.plot(x, y, label='Average Queue Length  Patients in CCU Queue', 
        color='red', linewidth=2.5, linestyle='--', marker='o', markersize=8)

# Add title and labels
ax.set_title('  Patients in CCU Queue', fontsize=14, fontweight='bold')
ax.set_xlabel('CCU Service rate', fontsize=12)
ax.set_ylabel('Average Queue Length', fontsize=12)

# Add legend and grid
ax.legend()
ax.grid(True, axis='y', linestyle='--', alpha=0.7)

# Display the plot
plt.tight_layout()
fig.show()
#fig.savefig('33.svg', format='svg')




# Data
x = [25, 35, 45]
y = [27.93, 46.96, 53.53]

# Configure font
mpl.rc('font', family='Times New Roman')
mpl.rc('font', size=12)

# Create the plot
fig, ax = plt.subplots(figsize=(8, 6))


# Highlight the line by changing its style
ax.plot(x, y, label='CCU Bed Utilization', 
        color='red', linewidth=2.5, linestyle='--', marker='o', markersize=8)

# Add title and labels
ax.set_title('CCU Bed Utilization', fontsize=14, fontweight='bold')
ax.set_xlabel('CCU Service rate', fontsize=12)
ax.set_ylabel('Bed Utilization', fontsize=12)

# Add legend and grid
ax.legend()
ax.grid(True, axis='y', linestyle='--', alpha=0.7)

# Display the plot
plt.tight_layout()
fig.show()
#fig.savefig('34.svg', format='svg')
# Out:
# C:\Users\Mahshad\AppData\Local\Temp\ipykernel_14428\2895732988.py:27: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# C:\Users\Mahshad\AppData\Local\Temp\ipykernel_14428\2895732988.py:57: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# C:\Users\Mahshad\AppData\Local\Temp\ipykernel_14428\2895732988.py:90: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
